# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()
 
cur.execute('select firstName,lastName, city, state from employees join offices using(officeCode) ORDER BY firstName, lastName;')
df = pd.DataFrame(cur.fetchall())
df.head(40)
# Out:
#            0          1              2           3
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# 19     Steve  Patterson         Boston          MA
# 20       Tom       King         Sydney
# 21   William  Patterson         Sydney
# 22   Yoshimi       Kato          Tokyo  Chiyoda-Ku

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cur.execute("""select customerName, orderNumber, orderDate, status from customers
                      JOIN orders 
                      using(customerNumber)""")
df = pd.DataFrame(cur.fetchall())
df.head(10)
# Out:
#                             0      1           2        3
# 0           Atelier graphique  10123  2003-05-20  Shipped
# 1           Atelier graphique  10298  2004-09-27  Shipped
# 2           Atelier graphique  10345  2004-11-25  Shipped
# 3          Signal Gift Stores  10124  2003-05-21  Shipped
# 4          Signal Gift Stores  10278  2004-08-06  Shipped
# 5          Signal Gift Stores  10346  2004-11-29  Shipped
# 6  Australian Collectors, Co.  10120  2003-04-29  Shipped
# 7  Australian Collectors, Co.  10125  2003-05-21  Shipped
# 8  Australian Collectors, Co.  10223  2004-02-20  Shipped
# 9  Australian Collectors, Co.  10342  2004-11-24  Shipped

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cur.execute("""select orderNumber, * from orders
                      JOIN orderdetails
                      using(orderNumber)""")
df = pd.DataFrame(cur.fetchall())
df.head(10)
# Out:
#       0      1           2           3           4        5   \
# 0  10100  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 1  10100  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 2  10100  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 3  10100  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 4  10101  10101  2003-01-09  2003-01-18  2003-01-11  Shipped
# 5  10101  10101  2003-01-09  2003-01-18  2003-01-11  Shipped
# 6  10101  10101  2003-01-09  2003-01-18  2003-01-11  Shipped
# 7  10101  10101  2003-01-09  2003-01-18  2003-01-11  Shipped
# 8  10102  10102  2003-01-10  2003-01-18  2003-01-14  Shipped
# 9  10102  10102  2003-01-10  2003-01-18  2003-01-14  Shipped
#
#                        6    7         8   9       10 11
# 0                          363  S18_1749  30  136.00  3
# 1                          363  S18_2248  50   55.09  2
# 2                          363  S18_4409  22   75.46  4
# 3                          363  S24_3969  49   35.29  1
# 4  Check on availability.  128  S18_2325  25  108.06  4
# 5  Check on availability.  128  S18_2795  26  167.06  1
# 6  Check on availability.  128  S24_1937  45   32.53  3
# 7  Check on availability.  128  S24_2022  46   44.35  2
# 8                          181  S18_1342  39   95.55  2
# 9                          181  S18_1367  41   43.13  1

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and allthe product information for each product in the order.

# %%
# Your code here
cur.execute("""select * from orders
                        join orderdetails
                        using(orderNumber)
                        join products
                        using(productCode);""")
df = pd.DataFrame(cur.fetchall())
df.head()
# Out:
#       0           1           2           3        4                       5   \
# 0  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 1  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 2  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 3  10100  2003-01-06  2003-01-13  2003-01-10  Shipped
# 4  10101  2003-01-09  2003-01-18  2003-01-11  Shipped  Check on availability.
#
#     6         7   8       9  10                                   11  \
# 0  363  S18_1749  30  136.00  3             1917 Grand Touring Sedan
# 1  363  S18_2248  50   55.09  2                   1911 Ford Town Car
# 2  363  S18_4409  22   75.46  4  1932 Alfa Romeo 8C2300 Spider Sport
# 3  363  S24_3969  49   35.29  1     1936 Mercedes Benz 500k Roadster
# 4  128  S18_2325  25  108.06  4            1932 Model A Ford J-Coupe
#
#              12    13                         14  \
# 0  Vintage Cars  1:18  Welly Diecast Productions
# 1  Vintage Cars  1:18    Motor City Art Classics
# 2  Vintage Cars  1:18              Exoto Designs
# 3  Vintage Cars  1:24          Red Start Diecast
# 4  Vintage Cars  1:18      Autoart Studio Design
#
#                                                   15    16     17      18
# 0  This 1:18 scale replica of the 1917 Grand Tour...  2724  86.70  170.00
# 1  Features opening hood, opening doors, opening ...   540  33.30   60.54
# 2  This 1:18 scale precision die cast replica fea...  6553  43.26   92.03
# 3  This model features grille-mounted chrome horn...  2081  21.75   41.03
# 4  This model features grille-mounted chrome horn...  9354  58.48  127.13

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
